# %% [markdown]
# <a href="https://colab.research.google.com/github/skku-taehwan/piazza_bonus/blob/main/bonus_point.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/tsnlab/piazza_bonus.git
# Out:
# Cloning into 'piazza_bonus'...
# remote: Enumerating objects: 27, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 27 (delta 7), reused 24 (delta 5), pack-reused 0
# Unpacking objects: 100% (27/27), done.

# %%
# !pip install -r ./piazza_bonus/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 97 kB 4.4 MB/s
# ...
#      |████████████████████████████████| 958 kB 48.8 MB/s
# ...
#      |████████████████████████████████| 359 kB 56.8 MB/s
# ...
#      |████████████████████████████████| 138 kB 58.6 MB/s
# ...
#      |████████████████████████████████| 55 kB 5.7 MB/s
# ...
#      |████████████████████████████████| 4.0 MB 41.9 MB/s
# ...
#      |████████████████████████████████| 58 kB 8.7 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# ...

# %%
# %cd piazza_bonus
# Out:
# /content/piazza_bonus

# %%
# !ls
# Out:
# main.py  README.md  requirements.txt

# %%
# !apt-get update
# !apt install chromium-chromedriver
# !cp /usr/lib/chromium-browser/dhromedriver /usr/bin
# !pip install selenium

# '''
# 하기 코드들 main.py에 추가해야 Webdriver Exception 에러 안 뜸.
# '''
# option.add_argument('--headless')
# option.add_argument('--no-sandbox')
# option.add_argument('--disable-dev-shm-usage')
# Out:
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:5 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:7 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:10 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Hit:11 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:12 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Hit:13 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Reading package lists... Done
# ...

# %%
# Chromedriver를 해당 폴더 내에 저장해야 함.
# !ls
# Out:
# chromedriver  main.py  README.md  requirements.txt

# %%
webdriver.Chrome(executable_path='chromedriver', options = options)
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="6910c3ce61d71437501866b1987d22a8")>

# %%
# !python3 main.py "https://piazza.com/class/kz8gaxcwmx56hi" 6 240 "abcdefu@skku.edu" "abcdefu"
# Out:
# defaultdict(<class 'list'>, {'김소현(2021####97)': [6], 'WANG CHENYANG(2022####85)': [6]})
# defaultdict(<class 'list'>, {'김소현(2021####97)': [6], 'WANG CHENYANG(2022####85)': [6]})
# defaultdict(<class 'list'>, {'김소현(2021####97)': [6], 'WANG CHENYANG(2022####85)': [6], '정재현(2020####72)': [8], '고태호(2021####02)': [8]})
# defaultdict(<class 'list'>, {'김소현(2021####97)': [6], 'WANG CHENYANG(2022####85)': [6], '정재현(2020####72)': [8], '고태호(2021####02)': [8], '박소민(2021####31)': [9], '이정윤(2021####02)': [9]})
# defaultdict(<class 'list'>, {'김소현(2021####97)': [6], 'WANG CHENYANG(2022####85)': [6], '정재현(2020####72)': [8], '고태호(2021####02)': [8], '박소민(2021####31)': [9], '이정윤(2021####02)': [9]})
# defaultdict(<class 'list'>, {'김소현(2021####97)': [6], 'WANG CHENYANG(2022####85)': [6], '정재현(2020####72)': [8], '고태호(2021####02)': [8], '박소민(2021####31)': [9], '이정윤(2021####02)': [9]})
# ...

# %%
# !pip install pandas
# !pip install numpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('output.csv')
df.head
# Out:
# <bound method NDFrame.head of     Unnamed: 0                StudentName  Count  \
# 0            0             Anonymous Poet      1
# 1            1  WANG CHENYANG(2022####85)      1
# 2            2            고아현(2021####90)      1
# 3            3            고태호(2021####02)      7
# 4            4            김서민(2020####72)      3
# 5            5            김소현(2021####97)      3
# 6            6                        김우주      3
# 7            7            김재경(2020####75)      1
# 8            8            김재준(2021####14)      1
# 9            9            김진나(2021####17)      1
# 10          10                        김진하      1
# 11          11            김태준(2021####03)      7
# 12          12            김하늘(2020####77)      3
# 13          13            김하빈(2021####83)      1
# 14          14                        남강민     11
# 15          15            노우혁(2020####48)      1
# 16          16            문호진(2021####48)      5
# ...

# %%
df
# Out:
#     Unnamed: 0                StudentName  Count  \
# 0            0             Anonymous Poet      1
# 1            1  WANG CHENYANG(2022####85)      1
# 2            2            고아현(2021####90)      1
# 3            3            고태호(2021####02)      7
# 4            4            김서민(2020####72)      3
# 5            5            김소현(2021####97)      3
# 6            6                        김우주      3
# 7            7            김재경(2020####75)      1
# 8            8            김재준(2021####14)      1
# 9            9            김진나(2021####17)      1
# 10          10                        김진하      1
# 11          11            김태준(2021####03)      7
# 12          12            김하늘(2020####77)      3
# 13          13            김하빈(2021####83)      1
# 14          14                        남강민     11
# 15          15            노우혁(2020####48)      1
# 16          16            문호진(2021####48)      5
# 17          17            박민수(2021####73)      2
# ...

# %%
df.to_csv('bonus_point.csv', encoding = 'cp949')
